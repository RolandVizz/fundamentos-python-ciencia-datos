# %% [markdown]
# <a href="https://colab.research.google.com/github/RolandVizz/fundamentos-python-ciencia-datos/blob/main/desafios_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Desafio 1**

# %% [markdown]
# 1. Importa el archivo [alumnos.csv](https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv) y almacena su contenido en un DataFrame de Pandas.

# %%
import pandas as pd

datos_alumnos = pd.read_csv('https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv')

# %% [markdown]
# 2. Visualiza las primeras 7 filas del DataFrame y las últimas 5.

# %%
print('Primeras 7 filas:')
datos_alumnos.head(7)
# Out:
# Primeras 7 filas:
#     Nombre  Edad  Nota Aprobado
# 0  Alberto    20   7.5     True
# 1      Ana    18   NaN    False
# 2   Camila    27   2.5    False
# 3    David    18   5.0    False
# 4    Brian    21  10.0     True
# 5    Bruna    23   NaN    False
# 6  Daniela    21   7.0     True

# %%
print('Últimas 5 filas:')
datos_alumnos.tail()
# Out:
# Últimas 5 filas:
#     Nombre  Edad  Nota   Aprobado
# 13  Miriam    25   9.0       True
# 14   Pablo    37   NaN      False
# 15  Milena    29   7.0       True
# 16   Lucas    33   NaN      False
# 17   Nadia    34   8.0  Verdadero

# %% [markdown]
# 3. Verifica la cantidad de filas y columnas en este DataFrame.

# %%
print('Filas, Columnas')
datos_alumnos.shape
# Out:
# Filas, Columnas
# (18, 4)

# %% [markdown]
# 4. Explora las columnas del DataFrame y analiza los tipos de datos presentes en cada columna.

# %%
datos_alumnos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nombre    18 non-null     object
#  1   Edad      18 non-null     int64
#  2   Nota      12 non-null     float64
#  3   Aprobado  18 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 708.0+ bytes

# %%
datos_alumnos.dtypes
# Out:
# Nombre       object
# Edad          int64
# Nota        float64
# Aprobado     object
# dtype: object

# %% [markdown]
# Extra: Calcula algunas estadísticas descriptivas básicas de los datos en el DataFrame (media, desviación estándar, etc.)

# %%
datos_alumnos.describe()
# Out:
#             Edad       Nota
# count  18.000000  12.000000
# mean   25.500000   6.841667
# std     6.070662   2.264532
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# # **Desafío 2**

# %% [markdown]
# ### Datos para validación

# %%
df_inmueble = pd.read_csv('https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv', sep=';')
df_inmueble.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %% [markdown]
# 1. Calcular el promedio de habitaciones por departamento.

# %%
media_habitaciones = df_inmueble.groupby('Tipo')[['Habitaciones']].mean()
media_habitaciones
# Out:
#                             Habitaciones
# Tipo
# Casa                            3.359633
# Casa Comercial                  1.801980
# Casa de Condominio              4.319672
# Casa de Vecindad                1.974684
# Cochera/Estacionamiento         0.064935
# Cocineta                        0.836088
# Conjunto Comercial/Sala         0.047175
# Departamento                    2.504199
# Departamento en Hotel           1.419780
# Edificio Completo               0.405530
# Estudio                         0.500000
# Galpón/Depósito/Almacén         0.069204
# Hotel                          25.500000
# Industria                       0.000000
# Loft                            1.078947
# Loteo/Condominio                0.000000
# Posada/Chalé                   23.000000
# Rancho                          5.125000
# Terreno Estándar                0.066667
# Tienda en Centro Comercial      0.055838
# Tienda/Salón                    0.011840

# %% [markdown]
# 2. Verificar cuántas colonias únicas existen en nuestra base de datos.

# %%
df_inmueble['Colonia'].unique()
# Out:
# array(['Condesa', 'Polanco', 'Santa Fe', 'Centro Histórico', 'Del Valle',
#        'Roma', 'Narvarte', 'Lomas de Chapultepec', 'Coyoacán',
#        'San Pedro de los Pinos', 'San Ángel', 'San Jerónimo',
#        'Ciudad de los Deportes', 'Villa Coapa', 'Bosques de las Lomas',
#        'Juárez', 'Chapultepec', 'Lindavista', 'La Condesa',
#        'San Miguel Chapultepec', 'Mixcoac', 'El Rosedal',
#        'Nueva Santa María', 'Arboledas', 'Villa de Cortés', 'Casa Blanca',
#        'Bosques de Aragón', 'La Florida', 'Álvaro Obregón', 'Iztacalco',
#        'Peralvillo', 'Napoles', 'Nativitas', 'San Rafael', 'Vallejo',
#        'Tlalpan', 'Pueblo Culhuacán', 'San Antonio Tecomitl',
#        'Roma Norte', 'Industrial Vallejo', 'Iztapalapa',
#        'Santa Marta Acatitla', 'Villa de Guadalupe', 'Tláhuac',
#        'Lomas de Padierna', 'El Contadero', 'San Mateo', 'Las Águilas',
#        'Culhuacán CTM', 'Santa María la Ribera', 'El Arenal',
# ...

# %%
df_inmueble['Colonia'].nunique()
# Out:
# 88

# %% [markdown]
# 3. Analizar qué colonias tienen el promedio de alquiler más alto.

# %%
media_alquiler_colonia = df_inmueble.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False)
media_alquiler_colonia.plot(kind='bar',figsize=(16,8),color='purple')
# Out:
# <Axes: xlabel='Colonia'>

# %% [markdown]
# 4. Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.

# %%
media_alquiler_colonia.head(5).plot(kind='barh',figsize=(16,8),color='purple')
# Out:
# <Axes: ylabel='Colonia'>

# %% [markdown]
# # **Desafío 3**

# %% [markdown]
# 1. Verifica si la base de datos contiene datos nulos y, en caso de tenerlos, realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.

# %%
datos_alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
datos_alumnos = datos_alumnos.fillna(0)
datos_alumnos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        0
# Aprobado    0
# dtype: int64

# %% [markdown]
# 2. Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.

# %%
datos_alumnos.drop(datos_alumnos.query('Nombre == "Carlos" | Nombre == "Alicia"').index, axis=0,inplace=True)
datos_alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
datos_alumnos.query('Nombre == "Carlos" | Nombre == "Alicia"')
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado]
# Index: []

# %% [markdown]
# 3. Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.

# %%
filtro_aprobados = datos_alumnos['Aprobado'] == 'True'
df = datos_alumnos[filtro_aprobados]
df
# Out:
#       Nombre  Edad  Nota Aprobado
# 0    Alberto    20   7.5     True
# 4      Brian    21  10.0     True
# 6    Daniela    21   7.0     True
# 12  Stephany    26  10.0     True
# 13    Miriam    25   9.0     True
# 15    Milena    29   7.0     True

# %% [markdown]
# 4. Guarda el DataFrame que contiene solo a los estudiantes aprobados en un archivo CSV llamado "alumnos_aprobados.csv".

# %%
df.to_csv('aprobados.csv',index=False)

# %% [markdown]
# Extra: Al revisar las calificaciones de los estudiantes aprobados, notamos que algunas calificaciones eran incorrectas. Las estudiantes que obtuvieron una calificación de 7.0, en realidad tenían un punto extra que no se contabilizó. Por lo tanto, reemplaza las calificaciones de 7.0 en la base de datos por 8.0.

# %%
df_corregido = datos_alumnos.replace(7,8)
df2 = df_corregido[(df_corregido['Nota'] >= 7)]
df2.to_csv('aprobados (corregido).csv',index=False)
df2
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   8.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   8.0       True
# 17     Nadia    34   8.0  Verdadero

# %% [markdown]
# # Desafío 4

# %% [markdown]
# 1. Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual. Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.

# %%
datos_alumnos['Puntos_extra'] = datos_alumnos['Nota'] * .40
datos_alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado  Puntos_extra
# 0  Alberto    20   7.5     True           3.0
# 1      Ana    18   0.0    False           0.0
# 2   Camila    27   2.5    False           1.0
# 3    David    18   5.0    False           2.0
# 4    Brian    21  10.0     True           4.0

# %% [markdown]
# 2. Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras.

# %%
datos_alumnos['Notas_finales'] = datos_alumnos['Nota'] + datos_alumnos['Puntos_extra']
datos_alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado  Puntos_extra  Notas_finales
# 0  Alberto    20   7.5     True           3.0           10.5
# 1      Ana    18   0.0    False           0.0            0.0
# 2   Camila    27   2.5    False           1.0            3.5
# 3    David    18   5.0    False           2.0            7.0
# 4    Brian    21  10.0     True           4.0           14.0

# %% [markdown]
# 3. Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:
#
# * True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
# * False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).

# %%
datos_alumnos['Aprobado_final'] = datos_alumnos['Notas_finales'].apply(lambda x: 'True' if x >= 7.0 else 'False')
datos_alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado  Puntos_extra  Notas_finales Aprobado_final
# 0  Alberto    20   7.5     True           3.0           10.5           True
# 1      Ana    18   0.0    False           0.0            0.0          False
# 2   Camila    27   2.5    False           1.0            3.5          False
# 3    David    18   5.0    False           2.0            7.0           True
# 4    Brian    21  10.0     True           4.0           14.0           True

# %% [markdown]
# 4. Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente, pero ahora fueron aprobados después de sumar los puntos extras.

# %%
datos_alumnos[datos_alumnos['Aprobado'] == 'False']
# Out:
#      Nombre  Edad  Nota Aprobado  Puntos_extra  Notas_finales Aprobado_final
# 1       Ana    18   0.0    False           0.0            0.0          False
# 2    Camila    27   2.5    False           1.0            3.5          False
# 3     David    18   5.0    False           2.0            7.0           True
# 5     Bruna    23   0.0    False           0.0            0.0          False
# 9    Victor    28   0.0    False           0.0            0.0          False
# 10   Danilo    21   0.0    False           0.0            0.0          False
# 11  Ignacio    24   4.5    False           1.8            6.3          False
# 14    Pablo    37   0.0    False           0.0            0.0          False
# 16    Lucas    33   0.0    False           0.0            0.0          False

# %%
filtro_nuevos_aprobados = (datos_alumnos['Aprobado'] == 'False') & (datos_alumnos['Aprobado_final'] == 'True')
datos_alumnos[filtro_nuevos_aprobados]
# Out:
#   Nombre  Edad  Nota Aprobado  Puntos_extra  Notas_finales Aprobado_final
# 3  David    18   5.0    False           2.0            7.0           True
